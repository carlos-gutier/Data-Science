# %%
import pandas as pd
import numpy as np
import dask.dataframe as dd
import dask.bag as db
import json
from sklearn.preprocessing import LabelEncoder

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
json_blob = '[{"id": 7, "Name": "L. Modri\\u0107", "Age": 32, "Photo": "https://cdn.sofifa.org/players/4/19/177003.png", "Nationality": "Croatia", "Club": "Real Madrid", "Position": "RCM", "Height": "5\'8", "Weight": "146lbs", "Overall": 91, "Potential": 91, "Value": 67000000, "Wage": 420000, "PreferredFoot": "Right", "WeakFoot": 4, "Crossing": 86, "Finishing": 72, "HeadingAccuracy": 55, "ShortPassing": 93, "Dribbling": 90, "SprintSpeed": 72, "Agility": 93, "ShotPower": 79, "Stamina": 89, "LongShots": 82, "Interceptions": 83, "Positioning": 79, "Vision": 92, "Marking": 60, "StandingTackle": 76, "SlidingTackle": 73, "GKDiving": 13, "GKHandling": 9, "GKKicking": 7, "GKPositioning": 14, "GKReflexes": 9, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 4, "WorkRate": "High/ High", "Volleys": 76, "Curve": 85, "FKAccuracy": 78, "LongPassing": 88, "BallControl": 93, "Acceleration": 80, "Reactions": 90, "Balance": 94, "Jumping": 68, "Strength": 58, "Aggression": 62, "Penalties": 82, "Composure": 84, "FieldPosition": "Midfield", "OvervalueRatio": "4.62", "FieldPositionNum": 3}, {"id": 9, "Name": "Sergio Ramos", "Age": 32, "Photo": "https://cdn.sofifa.org/players/4/19/155862.png", "Nationality": "Spain", "Club": "Real Madrid", "Position": "RCB", "Height": "6\'0", "Weight": "181lbs", "Overall": 91, "Potential": 91, "Value": 51000000, "Wage": 380000, "PreferredFoot": "Right", "WeakFoot": 3, "Crossing": 66, "Finishing": 60, "HeadingAccuracy": 91, "ShortPassing": 78, "Dribbling": 63, "SprintSpeed": 75, "Agility": 78, "ShotPower": 79, "Stamina": 84, "LongShots": 59, "Interceptions": 90, "Positioning": 60, "Vision": 63, "Marking": 87, "StandingTackle": 92, "SlidingTackle": 91, "GKDiving": 11, "GKHandling": 8, "GKKicking": 9, "GKPositioning": 7, "GKReflexes": 11, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 3, "WorkRate": "High/ Medium", "Volleys": 66, "Curve": 74, "FKAccuracy": 72, "LongPassing": 77, "BallControl": 84, "Acceleration": 76, "Reactions": 85, "Balance": 66, "Jumping": 93, "Strength": 83, "Aggression": 88, "Penalties": 75, "Composure": 82, "FieldPosition": "Defense", "OvervalueRatio": "4.18", "FieldPositionNum": 1}, {"id": 12, "Name": "T. Kroos", "Age": 28, "Photo": "https://cdn.sofifa.org/players/4/19/182521.png", "Nationality": "Germany", "Club": "Real Madrid", "Position": "LCM", "Height": "6\'0", "Weight": "168lbs", "Overall": 90, "Potential": 90, "Value": 76500000, "Wage": 355000, "PreferredFoot": "Right", "WeakFoot": 5, "Crossing": 88, "Finishing": 76, "HeadingAccuracy": 54, "ShortPassing": 92, "Dribbling": 81, "SprintSpeed": 62, "Agility": 70, "ShotPower": 87, "Stamina": 75, "LongShots": 92, "Interceptions": 82, "Positioning": 79, "Vision": 86, "Marking": 72, "StandingTackle": 79, "SlidingTackle": 69, "GKDiving": 10, "GKHandling": 11, "GKKicking": 13, "GKPositioning": 7, "GKReflexes": 10, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 3, "WorkRate": "Medium/ Medium", "Volleys": 82, "Curve": 86, "FKAccuracy": 84, "LongPassing": 93, "BallControl": 90, "Acceleration": 64, "Reactions": 89, "Balance": 71, "Jumping": 30, "Strength": 73, "Aggression": 60, "Penalties": 73, "Composure": 85, "FieldPosition": "Midfield", "OvervalueRatio": "3.94", "FieldPositionNum": 3}, {"id": 20, "Name": "T. Courtois", "Age": 26, "Photo": "https://cdn.sofifa.org/players/4/19/192119.png", "Nationality": "Belgium", "Club": "Real Madrid", "Position": "GK", "Height": "6\'6", "Weight": "212lbs", "Overall": 89, "Potential": 90, "Value": 53500000, "Wage": 240000, "PreferredFoot": "Left", "WeakFoot": 2, "Crossing": 14, "Finishing": 14, "HeadingAccuracy": 13, "ShortPassing": 33, "Dribbling": 13, "SprintSpeed": 52, "Agility": 61, "ShotPower": 36, "Stamina": 38, "LongShots": 17, "Interceptions": 15, "Positioning": 13, "Vision": 44, "Marking": 20, "StandingTackle": 18, "SlidingTackle": 16, "GKDiving": 85, "GKHandling": 91, "GKKicking": 72, "GKPositioning": 86, "GKReflexes": 88, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 1, "WorkRate": "Medium/ Medium", "Volleys": 12, "Curve": 19, "FKAccuracy": 20, "LongPassing": 35, "BallControl": 23, "Acceleration": 46, "Reactions": 84, "Balance": 45, "Jumping": 68, "Strength": 70, "Aggression": 23, "Penalties": 27, "Composure": 66, "FieldPosition": "GK", "OvervalueRatio": "2.70", "FieldPositionNum": 2}, {"id": 28, "Name": "Casemiro", "Age": 26, "Photo": "https://cdn.sofifa.org/players/4/19/200145.png", "Nationality": "Brazil", "Club": "Real Madrid", "Position": "CDM", "Height": "6\'1", "Weight": "185lbs", "Overall": 88, "Potential": 90, "Value": 59500000, "Wage": 285000, "PreferredFoot": "Right", "WeakFoot": 3, "Crossing": 52, "Finishing": 59, "HeadingAccuracy": 76, "ShortPassing": 85, "Dribbling": 69, "SprintSpeed": 65, "Agility": 62, "ShotPower": 86, "Stamina": 87, "LongShots": 79, "Interceptions": 87, "Positioning": 69, "Vision": 77, "Marking": 88, "StandingTackle": 90, "SlidingTackle": 87, "GKDiving": 13, "GKHandling": 14, "GKKicking": 16, "GKPositioning": 12, "GKReflexes": 12, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 2, "WorkRate": "Medium/ High", "Volleys": 53, "Curve": 59, "FKAccuracy": 74, "LongPassing": 82, "BallControl": 78, "Acceleration": 59, "Reactions": 84, "Balance": 66, "Jumping": 88, "Strength": 89, "Aggression": 87, "Penalties": 66, "Composure": 84, "FieldPosition": "Midfield", "OvervalueRatio": "3.24", "FieldPositionNum": 3}, {"id": 31, "Name": "Isco", "Age": 26, "Photo": "https://cdn.sofifa.org/players/4/19/197781.png", "Nationality": "Spain", "Club": "Real Madrid", "Position": "LW", "Height": "5\'9", "Weight": "174lbs", "Overall": 88, "Potential": 91, "Value": 73500000, "Wage": 315000, "PreferredFoot": "Right", "WeakFoot": 3, "Crossing": 75, "Finishing": 79, "HeadingAccuracy": 55, "ShortPassing": 89, "Dribbling": 94, "SprintSpeed": 69, "Agility": 87, "ShotPower": 69, "Stamina": 70, "LongShots": 87, "Interceptions": 64, "Positioning": 78, "Vision": 89, "Marking": 60, "StandingTackle": 64, "SlidingTackle": 51, "GKDiving": 10, "GKHandling": 8, "GKKicking": 12, "GKPositioning": 15, "GKReflexes": 6, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 4, "WorkRate": "High/ Medium", "Volleys": 65, "Curve": 88, "FKAccuracy": 76, "LongPassing": 83, "BallControl": 95, "Acceleration": 75, "Reactions": 77, "Balance": 90, "Jumping": 64, "Strength": 59, "Aggression": 58, "Penalties": 76, "Composure": 86, "FieldPosition": "Midfield", "OvervalueRatio": "3.58", "FieldPositionNum": 3}, {"id": 36, "Name": "Marcelo", "Age": 30, "Photo": "https://cdn.sofifa.org/players/4/19/176676.png", "Nationality": "Brazil", "Club": "Real Madrid", "Position": "LB", "Height": "5\'9", "Weight": "176lbs", "Overall": 88, "Potential": 88, "Value": 43000000, "Wage": 285000, "PreferredFoot": "Left", "WeakFoot": 4, "Crossing": 90, "Finishing": 70, "HeadingAccuracy": 75, "ShortPassing": 84, "Dribbling": 90, "SprintSpeed": 82, "Agility": 86, "ShotPower": 83, "Stamina": 91, "LongShots": 70, "Interceptions": 85, "Positioning": 85, "Vision": 82, "Marking": 71, "StandingTackle": 85, "SlidingTackle": 86, "GKDiving": 12, "GKHandling": 5, "GKKicking": 5, "GKPositioning": 5, "GKReflexes": 9, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 5, "WorkRate": "High/ Low", "Volleys": 54, "Curve": 85, "FKAccuracy": 67, "LongPassing": 76, "BallControl": 92, "Acceleration": 83, "Reactions": 88, "Balance": 86, "Jumping": 76, "Strength": 78, "Aggression": 84, "Penalties": 59, "Composure": 86, "FieldPosition": "Defense", "OvervalueRatio": "3.24", "FieldPositionNum": 1}, {"id": 37, "Name": "G. Bale", "Age": 28, "Photo": "https://cdn.sofifa.org/players/4/19/173731.png", "Nationality": "Wales", "Club": "Real Madrid", "Position": "ST", "Height": "6\'1", "Weight": "181lbs", "Overall": 88, "Potential": 88, "Value": 60000000, "Wage": 355000, "PreferredFoot": "Left", "WeakFoot": 3, "Crossing": 87, "Finishing": 86, "HeadingAccuracy": 84, "ShortPassing": 85, "Dribbling": 87, "SprintSpeed": 95, "Agility": 82, "ShotPower": 92, "Stamina": 75, "LongShots": 91, "Interceptions": 59, "Positioning": 85, "Vision": 79, "Marking": 54, "StandingTackle": 55, "SlidingTackle": 52, "GKDiving": 15, "GKHandling": 15, "GKKicking": 11, "GKPositioning": 5, "GKReflexes": 6, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 4, "WorkRate": "High/ Medium", "Volleys": 85, "Curve": 90, "FKAccuracy": 87, "LongPassing": 80, "BallControl": 85, "Acceleration": 94, "Reactions": 85, "Balance": 65, "Jumping": 87, "Strength": 80, "Aggression": 65, "Penalties": 76, "Composure": 86, "FieldPosition": "Attack", "OvervalueRatio": "4.03", "FieldPositionNum": 0}, {"id": 47, "Name": "K. Navas", "Age": 31, "Photo": "https://cdn.sofifa.org/players/4/19/193041.png", "Nationality": "Costa Rica", "Club": "Real Madrid", "Position": "GK", "Height": "6\'1", "Weight": "176lbs", "Overall": 87, "Potential": 87, "Value": 30500000, "Wage": 195000, "PreferredFoot": "Right", "WeakFoot": 3, "Crossing": 11, "Finishing": 15, "HeadingAccuracy": 11, "ShortPassing": 30, "Dribbling": 16, "SprintSpeed": 53, "Agility": 60, "ShotPower": 21, "Stamina": 39, "LongShots": 13, "Interceptions": 20, "Positioning": 16, "Vision": 68, "Marking": 28, "StandingTackle": 14, "SlidingTackle": 14, "GKDiving": 90, "GKHandling": 81, "GKKicking": 75, "GKPositioning": 82, "GKReflexes": 90, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 1, "WorkRate": "Medium/ Medium", "Volleys": 11, "Curve": 11, "FKAccuracy": 15, "LongPassing": 37, "BallControl": 19, "Acceleration": 54, "Reactions": 84, "Balance": 61, "Jumping": 74, "Strength": 75, "Aggression": 32, "Penalties": 25, "Composure": 67, "FieldPosition": "GK", "OvervalueRatio": "2.24", "FieldPositionNum": 2}, {"id": 63, "Name": "R. Varane", "Age": 25, "Photo": "https://cdn.sofifa.org/players/4/19/201535.png", "Nationality": "France", "Club": "Real Madrid", "Position": "RCB", "Height": "6\'3", "Weight": "179lbs", "Overall": 86, "Potential": 91, "Value": 50000000, "Wage": 210000, "PreferredFoot": "Right", "WeakFoot": 3, "Crossing": 36, "Finishing": 40, "HeadingAccuracy": 83, "ShortPassing": 75, "Dribbling": 57, "SprintSpeed": 85, "Agility": 63, "ShotPower": 52, "Stamina": 73, "LongShots": 53, "Interceptions": 82, "Positioning": 44, "Vision": 56, "Marking": 87, "StandingTackle": 88, "SlidingTackle": 87, "GKDiving": 11, "GKHandling": 11, "GKKicking": 9, "GKPositioning": 5, "GKReflexes": 14, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 2, "WorkRate": "Medium/ High", "Volleys": 42, "Curve": 46, "FKAccuracy": 54, "LongPassing": 76, "BallControl": 77, "Acceleration": 83, "Reactions": 83, "Balance": 40, "Jumping": 79, "Strength": 84, "Aggression": 77, "Penalties": 43, "Composure": 82, "FieldPosition": "Defense", "OvervalueRatio": "2.44", "FieldPositionNum": 1}, {"id": 80, "Name": "Marco Asensio", "Age": 22, "Photo": "https://cdn.sofifa.org/players/4/19/220834.png", "Nationality": "Spain", "Club": "Real Madrid", "Position": "RW", "Height": "6\'0", "Weight": "168lbs", "Overall": 85, "Potential": 92, "Value": 54000000, "Wage": 215000, "PreferredFoot": "Left", "WeakFoot": 3, "Crossing": 82, "Finishing": 82, "HeadingAccuracy": 50, "ShortPassing": 83, "Dribbling": 86, "SprintSpeed": 82, "Agility": 79, "ShotPower": 86, "Stamina": 76, "LongShots": 88, "Interceptions": 45, "Positioning": 82, "Vision": 84, "Marking": 40, "StandingTackle": 42, "SlidingTackle": 39, "GKDiving": 13, "GKHandling": 9, "GKKicking": 6, "GKPositioning": 12, "GKReflexes": 10, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 4, "WorkRate": "High/ Medium", "Volleys": 79, "Curve": 83, "FKAccuracy": 76, "LongPassing": 82, "BallControl": 85, "Acceleration": 85, "Reactions": 82, "Balance": 76, "Jumping": 58, "Strength": 61, "Aggression": 45, "Penalties": 62, "Composure": 83, "FieldPosition": "Midfield", "OvervalueRatio": "2.53", "FieldPositionNum": 3}, {"id": 106, "Name": "K. Benzema", "Age": 30, "Photo": "https://cdn.sofifa.org/players/4/19/165153.png", "Nationality": "France", "Club": "Real Madrid", "Position": "ST", "Height": "6\'1", "Weight": "179lbs", "Overall": 85, "Potential": 85, "Value": 37000000, "Wage": 240000, "PreferredFoot": "Right", "WeakFoot": 4, "Crossing": 75, "Finishing": 81, "HeadingAccuracy": 80, "ShortPassing": 83, "Dribbling": 83, "SprintSpeed": 76, "Agility": 76, "ShotPower": 81, "Stamina": 75, "LongShots": 75, "Interceptions": 22, "Positioning": 86, "Vision": 85, "Marking": 47, "StandingTackle": 15, "SlidingTackle": 12, "GKDiving": 13, "GKHandling": 11, "GKKicking": 5, "GKPositioning": 5, "GKReflexes": 7, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 4, "WorkRate": "Medium/ Low", "Volleys": 82, "Curve": 79, "FKAccuracy": 73, "LongPassing": 62, "BallControl": 86, "Acceleration": 76, "Reactions": 83, "Balance": 66, "Jumping": 73, "Strength": 80, "Aggression": 65, "Penalties": 82, "Composure": 79, "FieldPosition": "Attack", "OvervalueRatio": "2.82", "FieldPositionNum": 0}, {"id": 124, "Name": "Carvajal", "Age": 26, "Photo": "https://cdn.sofifa.org/players/4/19/204963.png", "Nationality": "Spain", "Club": "Real Madrid", "Position": "RB", "Height": "5\'8", "Weight": "161lbs", "Overall": 84, "Potential": 87, "Value": 31500000, "Wage": 185000, "PreferredFoot": "Right", "WeakFoot": 3, "Crossing": 83, "Finishing": 41, "HeadingAccuracy": 70, "ShortPassing": 81, "Dribbling": 76, "SprintSpeed": 84, "Agility": 81, "ShotPower": 64, "Stamina": 84, "LongShots": 36, "Interceptions": 83, "Positioning": 61, "Vision": 57, "Marking": 83, "StandingTackle": 83, "SlidingTackle": 85, "GKDiving": 13, "GKHandling": 13, "GKKicking": 15, "GKPositioning": 9, "GKReflexes": 15, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 3, "WorkRate": "High/ High", "Volleys": 34, "Curve": 72, "FKAccuracy": 47, "LongPassing": 71, "BallControl": 83, "Acceleration": 79, "Reactions": 82, "Balance": 79, "Jumping": 76, "Strength": 74, "Aggression": 81, "Penalties": 45, "Composure": 77, "FieldPosition": "Defense", "OvervalueRatio": "2.20", "FieldPositionNum": 1}, {"id": 173, "Name": "Lucas V\\u00e1zquez", "Age": 27, "Photo": "https://cdn.sofifa.org/players/4/19/208618.png", "Nationality": "Spain", "Club": "Real Madrid", "Position": "RW", "Height": "5\'8", "Weight": "154lbs", "Overall": 83, "Potential": 83, "Value": 27000000, "Wage": 205000, "PreferredFoot": "Right", "WeakFoot": 4, "Crossing": 86, "Finishing": 73, "HeadingAccuracy": 52, "ShortPassing": 83, "Dribbling": 82, "SprintSpeed": 79, "Agility": 79, "ShotPower": 82, "Stamina": 90, "LongShots": 80, "Interceptions": 44, "Positioning": 81, "Vision": 83, "Marking": 42, "StandingTackle": 50, "SlidingTackle": 44, "GKDiving": 9, "GKHandling": 16, "GKKicking": 9, "GKPositioning": 9, "GKReflexes": 7, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 4, "WorkRate": "High/ High", "Volleys": 54, "Curve": 82, "FKAccuracy": 75, "LongPassing": 75, "BallControl": 83, "Acceleration": 84, "Reactions": 85, "Balance": 84, "Jumping": 68, "Strength": 57, "Aggression": 65, "Penalties": 56, "Composure": 75, "FieldPosition": "Midfield", "OvervalueRatio": "2.47", "FieldPositionNum": 3}, {"id": 189, "Name": "Nacho Fern\\u00e1ndez", "Age": 28, "Photo": "https://cdn.sofifa.org/players/4/19/200724.png", "Nationality": "Spain", "Club": "Real Madrid", "Position": "CB", "Height": "5\'11", "Weight": "168lbs", "Overall": 83, "Potential": 85, "Value": 24500000, "Wage": 180000, "PreferredFoot": "Right", "WeakFoot": 4, "Crossing": 70, "Finishing": 32, "HeadingAccuracy": 82, "ShortPassing": 80, "Dribbling": 55, "SprintSpeed": 79, "Agility": 60, "ShotPower": 54, "Stamina": 78, "LongShots": 28, "Interceptions": 81, "Positioning": 37, "Vision": 53, "Marking": 75, "StandingTackle": 86, "SlidingTackle": 85, "GKDiving": 12, "GKHandling": 7, "GKKicking": 10, "GKPositioning": 15, "GKReflexes": 7, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 2, "WorkRate": "Medium/ High", "Volleys": 38, "Curve": 55, "FKAccuracy": 37, "LongPassing": 61, "BallControl": 78, "Acceleration": 70, "Reactions": 79, "Balance": 68, "Jumping": 81, "Strength": 79, "Aggression": 78, "Penalties": 45, "Composure": 73, "FieldPosition": "Defense", "OvervalueRatio": "2.17", "FieldPositionNum": 1}, {"id": 329, "Name": "Dani Ceballos", "Age": 21, "Photo": "https://cdn.sofifa.org/players/4/19/222509.png", "Nationality": "Spain", "Club": "Real Madrid", "Position": "LCM", "Height": "5\'10", "Weight": "154lbs", "Overall": 81, "Potential": 88, "Value": 25000000, "Wage": 120000, "PreferredFoot": "Right", "WeakFoot": 3, "Crossing": 74, "Finishing": 68, "HeadingAccuracy": 41, "ShortPassing": 83, "Dribbling": 85, "SprintSpeed": 67, "Agility": 82, "ShotPower": 64, "Stamina": 75, "LongShots": 71, "Interceptions": 76, "Positioning": 76, "Vision": 83, "Marking": 62, "StandingTackle": 75, "SlidingTackle": 74, "GKDiving": 12, "GKHandling": 15, "GKKicking": 16, "GKPositioning": 7, "GKReflexes": 13, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 4, "WorkRate": "Medium/ Medium", "Volleys": 62, "Curve": 73, "FKAccuracy": 63, "LongPassing": 80, "BallControl": 85, "Acceleration": 73, "Reactions": 80, "Balance": 79, "Jumping": 52, "Strength": 62, "Aggression": 76, "Penalties": 55, "Composure": 80, "FieldPosition": "Midfield", "OvervalueRatio": "1.48", "FieldPositionNum": 3}, {"id": 418, "Name": "Odriozola", "Age": 22, "Photo": "https://cdn.sofifa.org/players/4/19/234035.png", "Nationality": "Spain", "Club": "Real Madrid", "Position": "RB", "Height": "5\'9", "Weight": "146lbs", "Overall": 80, "Potential": 88, "Value": 18500000, "Wage": 115000, "PreferredFoot": "Right", "WeakFoot": 3, "Crossing": 81, "Finishing": 45, "HeadingAccuracy": 73, "ShortPassing": 77, "Dribbling": 69, "SprintSpeed": 82, "Agility": 78, "ShotPower": 58, "Stamina": 80, "LongShots": 59, "Interceptions": 75, "Positioning": 68, "Vision": 63, "Marking": 83, "StandingTackle": 79, "SlidingTackle": 80, "GKDiving": 11, "GKHandling": 12, "GKKicking": 10, "GKPositioning": 5, "GKReflexes": 14, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 3, "WorkRate": "High/ Medium", "Volleys": 48, "Curve": 69, "FKAccuracy": 30, "LongPassing": 70, "BallControl": 77, "Acceleration": 80, "Reactions": 77, "Balance": 79, "Jumping": 71, "Strength": 63, "Aggression": 63, "Penalties": 62, "Composure": 69, "FieldPosition": "Defense", "OvervalueRatio": "1.44", "FieldPositionNum": 1}, {"id": 431, "Name": "Mariano", "Age": 24, "Photo": "https://cdn.sofifa.org/players/4/19/221639.png", "Nationality": "Dominican Republic", "Club": "Real Madrid", "Position": "ST", "Height": "5\'11", "Weight": "168lbs", "Overall": 80, "Potential": 85, "Value": 20000000, "Wage": 140000, "PreferredFoot": "Right", "WeakFoot": 4, "Crossing": 50, "Finishing": 81, "HeadingAccuracy": 82, "ShortPassing": 69, "Dribbling": 75, "SprintSpeed": 85, "Agility": 79, "ShotPower": 85, "Stamina": 81, "LongShots": 82, "Interceptions": 45, "Positioning": 79, "Vision": 63, "Marking": 41, "StandingTackle": 40, "SlidingTackle": 34, "GKDiving": 12, "GKHandling": 14, "GKKicking": 6, "GKPositioning": 8, "GKReflexes": 15, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 3, "WorkRate": "High/ Medium", "Volleys": 70, "Curve": 76, "FKAccuracy": 76, "LongPassing": 51, "BallControl": 72, "Acceleration": 84, "Reactions": 82, "Balance": 72, "Jumping": 92, "Strength": 79, "Aggression": 86, "Penalties": 75, "Composure": 68, "FieldPosition": "Attack", "OvervalueRatio": "1.75", "FieldPositionNum": 0}, {"id": 571, "Name": "Marcos Llorente", "Age": 23, "Photo": "https://cdn.sofifa.org/players/4/19/226161.png", "Nationality": "Spain", "Club": "Real Madrid", "Position": "CDM", "Height": "6\'0", "Weight": "161lbs", "Overall": 79, "Potential": 87, "Value": 16000000, "Wage": 110000, "PreferredFoot": "Right", "WeakFoot": 3, "Crossing": 56, "Finishing": 39, "HeadingAccuracy": 61, "ShortPassing": 84, "Dribbling": 68, "SprintSpeed": 59, "Agility": 58, "ShotPower": 58, "Stamina": 75, "LongShots": 56, "Interceptions": 80, "Positioning": 65, "Vision": 76, "Marking": 76, "StandingTackle": 79, "SlidingTackle": 72, "GKDiving": 13, "GKHandling": 6, "GKKicking": 6, "GKPositioning": 11, "GKReflexes": 15, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 3, "WorkRate": "Medium/ Medium", "Volleys": 44, "Curve": 45, "FKAccuracy": 51, "LongPassing": 81, "BallControl": 78, "Acceleration": 61, "Reactions": 74, "Balance": 66, "Jumping": 66, "Strength": 72, "Aggression": 65, "Penalties": 53, "Composure": 76, "FieldPosition": "Midfield", "OvervalueRatio": "1.39", "FieldPositionNum": 3}, {"id": 694, "Name": "Kiko Casilla", "Age": 31, "Photo": "https://cdn.sofifa.org/players/4/19/177644.png", "Nationality": "Spain", "Club": "Real Madrid", "Position": "GK", "Height": "6\'3", "Weight": "190lbs", "Overall": 79, "Potential": 79, "Value": 7500000, "Wage": 105000, "PreferredFoot": "Right", "WeakFoot": 2, "Crossing": 24, "Finishing": 14, "HeadingAccuracy": 13, "ShortPassing": 30, "Dribbling": 12, "SprintSpeed": 49, "Agility": 43, "ShotPower": 24, "Stamina": 43, "LongShots": 13, "Interceptions": 20, "Positioning": 12, "Vision": 52, "Marking": 26, "StandingTackle": 15, "SlidingTackle": 11, "GKDiving": 74, "GKHandling": 81, "GKKicking": 79, "GKPositioning": 81, "GKReflexes": 77, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 1, "WorkRate": "Medium/ Medium", "Volleys": 12, "Curve": 25, "FKAccuracy": 25, "LongPassing": 24, "BallControl": 20, "Acceleration": 32, "Reactions": 74, "Balance": 58, "Jumping": 69, "Strength": 79, "Aggression": 45, "Penalties": 23, "Composure": 60, "FieldPosition": "GK", "OvervalueRatio": "1.33", "FieldPositionNum": 2}, {"id": 751, "Name": "Vallejo", "Age": 21, "Photo": "https://cdn.sofifa.org/players/4/19/225161.png", "Nationality": "Spain", "Club": "Real Madrid", "Position": "CB", "Height": "6\'0", "Weight": "174lbs", "Overall": 78, "Potential": 86, "Value": 13500000, "Wage": 81000, "PreferredFoot": "Right", "WeakFoot": 3, "Crossing": 41, "Finishing": 44, "HeadingAccuracy": 74, "ShortPassing": 76, "Dribbling": 56, "SprintSpeed": 74, "Agility": 69, "ShotPower": 49, "Stamina": 66, "LongShots": 31, "Interceptions": 82, "Positioning": 32, "Vision": 33, "Marking": 79, "StandingTackle": 78, "SlidingTackle": 81, "GKDiving": 10, "GKHandling": 13, "GKKicking": 15, "GKPositioning": 13, "GKReflexes": 6, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 2, "WorkRate": "Low/ High", "Volleys": 36, "Curve": 29, "FKAccuracy": 31, "LongPassing": 75, "BallControl": 67, "Acceleration": 67, "Reactions": 77, "Balance": 69, "Jumping": 77, "Strength": 69, "Aggression": 74, "Penalties": 45, "Composure": 76, "FieldPosition": "Defense", "OvervalueRatio": "1.04", "FieldPositionNum": 1}, {"id": 1135, "Name": "Vin\\u00edcius J\\u00fanior", "Age": 17, "Photo": "https://cdn.sofifa.org/players/4/19/238794.png", "Nationality": "Brazil", "Club": "Real Madrid", "Position": "LW", "Height": "5\'9", "Weight": "161lbs", "Overall": 77, "Potential": 92, "Value": 17500000, "Wage": 66000, "PreferredFoot": "Right", "WeakFoot": 4, "Crossing": 65, "Finishing": 70, "HeadingAccuracy": 50, "ShortPassing": 70, "Dribbling": 81, "SprintSpeed": 94, "Agility": 90, "ShotPower": 74, "Stamina": 79, "LongShots": 68, "Interceptions": 26, "Positioning": 74, "Vision": 69, "Marking": 32, "StandingTackle": 25, "SlidingTackle": 18, "GKDiving": 5, "GKHandling": 7, "GKKicking": 7, "GKPositioning": 7, "GKReflexes": 10, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 5, "WorkRate": "High/ Medium", "Volleys": 71, "Curve": 77, "FKAccuracy": 62, "LongPassing": 48, "BallControl": 80, "Acceleration": 92, "Reactions": 70, "Balance": 82, "Jumping": 74, "Strength": 59, "Aggression": 48, "Penalties": 65, "Composure": 75, "FieldPosition": "Midfield", "OvervalueRatio": "0.86", "FieldPositionNum": 3}, {"id": 2484, "Name": "F. Valverde", "Age": 19, "Photo": "https://cdn.sofifa.org/players/4/19/239053.png", "Nationality": "Uruguay", "Club": "Real Madrid", "Position": "CM", "Height": "6\'0", "Weight": "172lbs", "Overall": 74, "Potential": 84, "Value": 8500000, "Wage": 46000, "PreferredFoot": "Right", "WeakFoot": 3, "Crossing": 49, "Finishing": 67, "HeadingAccuracy": 48, "ShortPassing": 78, "Dribbling": 70, "SprintSpeed": 68, "Agility": 51, "ShotPower": 77, "Stamina": 68, "LongShots": 77, "Interceptions": 68, "Positioning": 61, "Vision": 75, "Marking": 70, "StandingTackle": 67, "SlidingTackle": 50, "GKDiving": 6, "GKHandling": 10, "GKKicking": 6, "GKPositioning": 15, "GKReflexes": 8, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 3, "WorkRate": "Medium/ Medium", "Volleys": 38, "Curve": 51, "FKAccuracy": 48, "LongPassing": 81, "BallControl": 74, "Acceleration": 69, "Reactions": 69, "Balance": 64, "Jumping": 49, "Strength": 56, "Aggression": 59, "Penalties": 42, "Composure": 70, "FieldPosition": "Midfield", "OvervalueRatio": "0.62", "FieldPositionNum": 3}, {"id": 6613, "Name": "Reguil\\u00f3n", "Age": 21, "Photo": "https://cdn.sofifa.org/players/4/19/245279.png", "Nationality": "Spain", "Club": "Real Madrid", "Position": "LB", "Height": "5\'10", "Weight": "150lbs", "Overall": 68, "Potential": 80, "Value": 1400000, "Wage": 28000, "PreferredFoot": "Left", "WeakFoot": 3, "Crossing": 66, "Finishing": 22, "HeadingAccuracy": 59, "ShortPassing": 62, "Dribbling": 63, "SprintSpeed": 72, "Agility": 52, "ShotPower": 54, "Stamina": 72, "LongShots": 33, "Interceptions": 67, "Positioning": 56, "Vision": 54, "Marking": 66, "StandingTackle": 68, "SlidingTackle": 68, "GKDiving": 11, "GKHandling": 14, "GKKicking": 9, "GKPositioning": 5, "GKReflexes": 12, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 3, "WorkRate": "High/ Medium", "Volleys": 18, "Curve": 50, "FKAccuracy": 39, "LongPassing": 44, "BallControl": 67, "Acceleration": 74, "Reactions": 66, "Balance": 71, "Jumping": 60, "Strength": 45, "Aggression": 58, "Penalties": 42, "Composure": 64, "FieldPosition": "Defense", "OvervalueRatio": "0.41", "FieldPositionNum": 1}, {"id": 8589, "Name": "Javi S\\u00e1nchez", "Age": 21, "Photo": "https://cdn.sofifa.org/players/4/19/245238.png", "Nationality": "Spain", "Club": "Real Madrid", "Position": "CB", "Height": "6\'2", "Weight": "170lbs", "Overall": 67, "Potential": 79, "Value": 1200000, "Wage": 24000, "PreferredFoot": "Right", "WeakFoot": 3, "Crossing": 32, "Finishing": 28, "HeadingAccuracy": 66, "ShortPassing": 63, "Dribbling": 34, "SprintSpeed": 64, "Agility": 41, "ShotPower": 38, "Stamina": 68, "LongShots": 32, "Interceptions": 67, "Positioning": 25, "Vision": 35, "Marking": 64, "StandingTackle": 67, "SlidingTackle": 65, "GKDiving": 11, "GKHandling": 15, "GKKicking": 13, "GKPositioning": 8, "GKReflexes": 13, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 2, "WorkRate": "Medium/ Medium", "Volleys": 18, "Curve": 27, "FKAccuracy": 34, "LongPassing": 38, "BallControl": 61, "Acceleration": 55, "Reactions": 63, "Balance": 51, "Jumping": 72, "Strength": 68, "Aggression": 70, "Penalties": 38, "Composure": 55, "FieldPosition": "Defense", "OvervalueRatio": "0.36", "FieldPositionNum": 1}, {"id": 8993, "Name": "Cristo Gonz\\u00e1lez", "Age": 20, "Photo": "https://cdn.sofifa.org/players/4/19/225105.png", "Nationality": "Spain", "Club": "Real Madrid", "Position": "ST", "Height": "5\'10", "Weight": "163lbs", "Overall": 66, "Potential": 78, "Value": 1200000, "Wage": 26000, "PreferredFoot": "Right", "WeakFoot": 2, "Crossing": 54, "Finishing": 70, "HeadingAccuracy": 58, "ShortPassing": 64, "Dribbling": 69, "SprintSpeed": 70, "Agility": 70, "ShotPower": 65, "Stamina": 63, "LongShots": 63, "Interceptions": 29, "Positioning": 68, "Vision": 67, "Marking": 45, "StandingTackle": 39, "SlidingTackle": 26, "GKDiving": 11, "GKHandling": 9, "GKKicking": 13, "GKPositioning": 9, "GKReflexes": 13, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 3, "WorkRate": "Medium/ Medium", "Volleys": 60, "Curve": 64, "FKAccuracy": 50, "LongPassing": 60, "BallControl": 68, "Acceleration": 73, "Reactions": 60, "Balance": 71, "Jumping": 65, "Strength": 49, "Aggression": 52, "Penalties": 54, "Composure": 61, "FieldPosition": "Attack", "OvervalueRatio": "0.39", "FieldPositionNum": 0}, {"id": 10017, "Name": "F. Feuillassier", "Age": 20, "Photo": "https://cdn.sofifa.org/players/4/19/241467.png", "Nationality": "Argentina", "Club": "Real Madrid", "Position": "LW", "Height": "5\'8", "Weight": "152lbs", "Overall": 65, "Potential": 80, "Value": 1200000, "Wage": 23000, "PreferredFoot": "Right", "WeakFoot": 4, "Crossing": 64, "Finishing": 72, "HeadingAccuracy": 49, "ShortPassing": 62, "Dribbling": 70, "SprintSpeed": 68, "Agility": 67, "ShotPower": 72, "Stamina": 62, "LongShots": 71, "Interceptions": 22, "Positioning": 58, "Vision": 56, "Marking": 35, "StandingTackle": 23, "SlidingTackle": 20, "GKDiving": 7, "GKHandling": 13, "GKKicking": 9, "GKPositioning": 13, "GKReflexes": 5, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 3, "WorkRate": "Medium/ Medium", "Volleys": 55, "Curve": 44, "FKAccuracy": 45, "LongPassing": 45, "BallControl": 65, "Acceleration": 68, "Reactions": 53, "Balance": 78, "Jumping": 47, "Strength": 61, "Aggression": 45, "Penalties": 50, "Composure": 54, "FieldPosition": "Midfield", "OvervalueRatio": "0.35", "FieldPositionNum": 3}, {"id": 10108, "Name": "Fidalgo", "Age": 21, "Photo": "https://cdn.sofifa.org/players/4/19/246608.png", "Nationality": "Spain", "Club": "Real Madrid", "Position": "CM", "Height": "5\'9", "Weight": "150lbs", "Overall": 65, "Potential": 75, "Value": 875000, "Wage": 20000, "PreferredFoot": "Right", "WeakFoot": 3, "Crossing": 61, "Finishing": 49, "HeadingAccuracy": 44, "ShortPassing": 69, "Dribbling": 68, "SprintSpeed": 63, "Agility": 68, "ShotPower": 54, "Stamina": 64, "LongShots": 48, "Interceptions": 52, "Positioning": 59, "Vision": 70, "Marking": 46, "StandingTackle": 51, "SlidingTackle": 47, "GKDiving": 10, "GKHandling": 9, "GKKicking": 10, "GKPositioning": 11, "GKReflexes": 9, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 3, "WorkRate": "High/ Medium", "Volleys": 46, "Curve": 62, "FKAccuracy": 53, "LongPassing": 65, "BallControl": 70, "Acceleration": 65, "Reactions": 62, "Balance": 77, "Jumping": 51, "Strength": 49, "Aggression": 62, "Penalties": 49, "Composure": 68, "FieldPosition": "Midfield", "OvervalueRatio": "0.31", "FieldPositionNum": 3}, {"id": 10992, "Name": "Sergio L\\u00f3pez", "Age": 19, "Photo": "https://cdn.sofifa.org/players/4/19/245287.png", "Nationality": "Spain", "Club": "Real Madrid", "Position": "RB", "Height": "5\'10", "Weight": "146lbs", "Overall": 64, "Potential": 80, "Value": 875000, "Wage": 9000, "PreferredFoot": "Right", "WeakFoot": 3, "Crossing": 63, "Finishing": 52, "HeadingAccuracy": 56, "ShortPassing": 61, "Dribbling": 64, "SprintSpeed": 79, "Agility": 69, "ShotPower": 63, "Stamina": 61, "LongShots": 59, "Interceptions": 60, "Positioning": 50, "Vision": 46, "Marking": 59, "StandingTackle": 61, "SlidingTackle": 62, "GKDiving": 12, "GKHandling": 12, "GKKicking": 11, "GKPositioning": 7, "GKReflexes": 13, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 3, "WorkRate": "High/ Medium", "Volleys": 48, "Curve": 57, "FKAccuracy": 41, "LongPassing": 56, "BallControl": 63, "Acceleration": 78, "Reactions": 63, "Balance": 72, "Jumping": 61, "Strength": 51, "Aggression": 62, "Penalties": 43, "Composure": 62, "FieldPosition": "Defense", "OvervalueRatio": "0.14", "FieldPositionNum": 1}, {"id": 11153, "Name": "Fran Garc\\u00eda", "Age": 18, "Photo": "https://cdn.sofifa.org/players/4/19/246606.png", "Nationality": "Spain", "Club": "Real Madrid", "Position": "LB", "Height": "5\'7", "Weight": "139lbs", "Overall": 64, "Potential": 79, "Value": 825000, "Wage": 9000, "PreferredFoot": "Left", "WeakFoot": 3, "Crossing": 65, "Finishing": 42, "HeadingAccuracy": 44, "ShortPassing": 57, "Dribbling": 62, "SprintSpeed": 79, "Agility": 68, "ShotPower": 47, "Stamina": 66, "LongShots": 45, "Interceptions": 62, "Positioning": 49, "Vision": 54, "Marking": 60, "StandingTackle": 58, "SlidingTackle": 59, "GKDiving": 9, "GKHandling": 6, "GKKicking": 12, "GKPositioning": 9, "GKReflexes": 11, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 2, "WorkRate": "High/ Medium", "Volleys": 39, "Curve": 55, "FKAccuracy": 36, "LongPassing": 49, "BallControl": 65, "Acceleration": 79, "Reactions": 62, "Balance": 89, "Jumping": 60, "Strength": 44, "Aggression": 63, "Penalties": 39, "Composure": 60, "FieldPosition": "Defense", "OvervalueRatio": "0.14", "FieldPositionNum": 1}, {"id": 11698, "Name": "Manu Hernando", "Age": 19, "Photo": "https://cdn.sofifa.org/players/4/19/243155.png", "Nationality": "Spain", "Club": "Real Madrid", "Position": "CB", "Height": "5\'11", "Weight": "170lbs", "Overall": 64, "Potential": 76, "Value": 700000, "Wage": 9000, "PreferredFoot": "Right", "WeakFoot": 3, "Crossing": 44, "Finishing": 32, "HeadingAccuracy": 68, "ShortPassing": 62, "Dribbling": 56, "SprintSpeed": 63, "Agility": 61, "ShotPower": 47, "Stamina": 66, "LongShots": 45, "Interceptions": 55, "Positioning": 43, "Vision": 37, "Marking": 70, "StandingTackle": 65, "SlidingTackle": 67, "GKDiving": 11, "GKHandling": 12, "GKKicking": 13, "GKPositioning": 12, "GKReflexes": 5, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 2, "WorkRate": "Medium/ Medium", "Volleys": 29, "Curve": 44, "FKAccuracy": 39, "LongPassing": 53, "BallControl": 64, "Acceleration": 61, "Reactions": 59, "Balance": 64, "Jumping": 59, "Strength": 62, "Aggression": 58, "Penalties": 42, "Composure": 47, "FieldPosition": "Defense", "OvervalueRatio": "0.14", "FieldPositionNum": 1}, {"id": 12319, "Name": "Dani G\\u00f3mez", "Age": 19, "Photo": "https://cdn.sofifa.org/players/4/19/243315.png", "Nationality": "Spain", "Club": "Real Madrid", "Position": "ST", "Height": "5\'10", "Weight": "154lbs", "Overall": 63, "Potential": 77, "Value": 800000, "Wage": 12000, "PreferredFoot": "Right", "WeakFoot": 3, "Crossing": 32, "Finishing": 67, "HeadingAccuracy": 58, "ShortPassing": 54, "Dribbling": 60, "SprintSpeed": 65, "Agility": 70, "ShotPower": 59, "Stamina": 51, "LongShots": 52, "Interceptions": 12, "Positioning": 61, "Vision": 42, "Marking": 41, "StandingTackle": 12, "SlidingTackle": 15, "GKDiving": 7, "GKHandling": 10, "GKKicking": 13, "GKPositioning": 8, "GKReflexes": 14, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 2, "WorkRate": "Medium/ Medium", "Volleys": 54, "Curve": 41, "FKAccuracy": 45, "LongPassing": 35, "BallControl": 66, "Acceleration": 66, "Reactions": 56, "Balance": 65, "Jumping": 62, "Strength": 70, "Aggression": 28, "Penalties": 57, "Composure": 44, "FieldPosition": "Attack", "OvervalueRatio": "0.19", "FieldPositionNum": 0}, {"id": 13443, "Name": "L. Zidane", "Age": 20, "Photo": "https://cdn.sofifa.org/players/4/19/240311.png", "Nationality": "France", "Club": "Real Madrid", "Position": "GK", "Height": "6\'0", "Weight": "170lbs", "Overall": 62, "Potential": 71, "Value": 350000, "Wage": 9000, "PreferredFoot": "Right", "WeakFoot": 3, "Crossing": 12, "Finishing": 8, "HeadingAccuracy": 12, "ShortPassing": 22, "Dribbling": 10, "SprintSpeed": 32, "Agility": 36, "ShotPower": 15, "Stamina": 38, "LongShots": 5, "Interceptions": 14, "Positioning": 5, "Vision": 45, "Marking": 13, "StandingTackle": 11, "SlidingTackle": 13, "GKDiving": 65, "GKHandling": 60, "GKKicking": 61, "GKPositioning": 62, "GKReflexes": 61, "ClubLogo": "https://cdn.sofifa.org/teams/2/light/243.png", "SkillMoves": 1, "WorkRate": "Medium/ Medium", "Volleys": 6, "Curve": 14, "FKAccuracy": 11, "LongPassing": 15, "BallControl": 14, "Acceleration": 33, "Reactions": 54, "Balance": 49, "Jumping": 63, "Strength": 50, "Aggression": 16, "Penalties": 19, "Composure": 36, "FieldPosition": "GK", "OvervalueRatio": "0.15", "FieldPositionNum": 2}]'

# %%
# reading JSON file
test_team = db.read_text('test_team.json').map(json.loads)
df_json = test_team.to_dataframe()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-14-414526cd65ed> in <module>
#       1 # reading JSON file
#       2 test_team = db.read_text('test_team.json').map(json.loads)
# ----> 3 df_json = test_team.to_dataframe()
#
# ~\Anaconda3\envs\py3\lib\site-packages\dask\bag\core.py in to_dataframe(self, meta, columns)
#    1331         import dask.dataframe as dd
#    1332         if meta is None:
# -> 1333             head = self.take(1, warn=False)
#    1334             if len(head) == 0:
#    1335                 raise ValueError("`dask.bag.Bag.to_dataframe` failed to "
#
# ~\Anaconda3\envs\py3\lib\site-packages\dask\bag\core.py in take(self, k, npartitions, compute, warn)
#    1208
#    1209         if compute:
# -> 1210             return tuple(b.compute())
#    1211         else:
#    1212             return b
#
# ...

# %%
test_team
# Out:
# dask.bag<loads-9..., npartitions=1>

# %%
# Entire Fifa19 dataframe
#data = pd.read_csv('/app/data/players_data.csv')
data = dd.read_csv('players_data.csv')

# %%
df_teams = df_json

# %% [markdown]
# ### Getting Club players

# %%
def get_club_players(df_teams):
    
    df_club_list = df_teams[['Name','Position','OvervalueRatio','Overall','Potential','Wage']]
    
    sort_club_list = df_club_list.sort_values(by='OvervalueRatio', ascending=False)

    df_top_2_rated_players = sort_club_list.head(2)

    df_bottom_2_rated_players = sort_club_list.tail(2)

    return df_club_list, df_top_2_rated_players, df_bottom_2_rated_players

# %%
df_attributes = data[['FieldPositionNum', 'Overall', 'Potential', 'Crossing', 'Finishing', 
                          'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve',
                          'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 
                          'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 
                          'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 
                          'Vision', 'Penalties', 'Composure', 'Marking']]

# %% [markdown]
# ### Recommender System

# %%
# Create function that uses above 'suggested' variables to output x players to potentially obtain by trade
# for df_attributes dataframe, see above cells

def get_suggested_trades(df_teams):  # player argument changed to 'club', after get_club_players refactored
    trades_p1 = []  # this will be the output object that club_suggested_changes receives/uses
    trades_p2 = []
    players_wages = []

    all_players, top_2, bottom_2 = get_club_players(df_teams)  # df_club_list, df_top_2_players, df_bottom_2_players

    # looping throught 2 player names in 'top_2'
    for idx, player in enumerate(top_2.Name):

        # getting 'index' for player in 'df_teams' DF
        input_player_index = df_teams[df_teams['Name']==player].index.values[0]

        # getting the 'Overall', 'Potential', and 'Field Position Num'
        p_overall = df_teams.iloc[input_player_index]['Overall']
        p_potential = df_teams.iloc[input_player_index]['Potential']
        p_position = df_teams.iloc[input_player_index]['FieldPositionNum']

        # getting 'Wage' for player in 'df_teams' DF
        # to be used later for 'Post-trade Leftover Wage' in returned DF
        input_player_wage = df_teams.iloc[input_player_index]['Wage']
        players_wages.append(input_player_wage)

        # getting 'row' for same player in 'df_attributes' using index (No 'Name' col in 'df_attributes')
        player_attributes = df_attributes.iloc[input_player_index]

        # filtering attributes logic:
        filtered_attributes = df_attributes[(df_attributes['Overall'] > p_overall-10) 
                                        & (df_attributes['Potential'] > p_potential-10)
                                        & (df_attributes['FieldPositionNum'] == p_position)]

        # use filter logic to suggest replacement players - top 5 suggested
        # gives DF of with all indexes and correlation ratio
        suggested_players = filtered_attributes.corrwith(player_attributes, axis=1)

        # Top 2 suggested players (most positively correlated)
        suggested_players = suggested_players.sort_values(ascending=False).head(6)

        cols = ['Name', 'Position', 'OvervalueRatio', 'Overall', 'Potential', 'Wage']
        for i, corr in enumerate(suggested_players):
            if idx == 0:
                # player 1 - suggested trades
                trades_p1.append(data[data.index==suggested_players.index[i]][cols].values)
            else:
                # player 2 - suggested trades                 
                trades_p2.append(data[data.index==suggested_players.index[i]][cols].values)

    cols1 = ['Name', 'Position', 'OvervalueRatio', 'Overall', 'Potential', 'Wage']
    # suggested trades DF for player 1 - dropping 1st row (most positively correlated = same as player 1)
    trades_p1_df = pd.DataFrame(np.row_stack(trades_p1), columns=cols1)
    trades_p1_df = trades_p1_df.drop(trades_p1_df.index[0]).reset_index(drop=True)
    
    # suggested trades DF for player 2 - dropping 1st row (most positively correlated = same as player 2)
    trades_p2_df = pd.DataFrame(np.row_stack(trades_p2), columns=cols1)
    trades_p2_df = trades_p2_df.drop(trades_p2_df.index[0]).reset_index(drop=True)
    
    #adding 'Post-trade Leftover Wage' column to each returned DF
    trades_p1_df['Post-tradeLeftoverWage'] = players_wages[0] - trades_p1_df['Wage']
    trades_p2_df['Post-tradeLeftoverWage'] = players_wages[1] - trades_p2_df['Wage']
    
    return top_2, bottom_2, trades_p1_df, trades_p2_df

# %%
# See comment line inside of function just below
def get_replacement_players(df_teams):
    '''Gets 2 lowest-rated players, and suggests four possible replacements.'''
    replacements_p1 = []  # this will be the output object that club_suggested_changes receives/uses
    replacements_p2 = []
    players_wages = []

    
    all_players, top_2, bottom_2 = get_club_players(df_teams)  # df_club_list, df_top_2_players, df_bottom_2_players

    # looping throught 2 player names in 'top_2'
    for idx, player in enumerate(bottom_2.Name):

        # getting 'index' for player in 'df_teams' DF
        input_player_index = df_teams[df_teams['Name']==player].index.values[0]

        # getting the 'Overall', 'Potential', and 'Field Position Num'
        p_overall = df_teams.iloc[input_player_index]['Overall']
        p_potential = df_teams.iloc[input_player_index]['Potential']
        p_position = df_teams.iloc[input_player_index]['FieldPositionNum']

        # getting 'Wage' for player in 'df_teams' DF
        # to be used later for 'Post-trade Leftover Wage' in returned DF
        input_player_wage = df_teams.iloc[input_player_index]['Wage']
        players_wages.append(input_player_wage)

        # getting 'row' for same player in 'df_attributes' using index (No 'Name' col in 'df_attributes')
        player_attributes = df_attributes.iloc[input_player_index]

        # filtering weak attributes logic:
        filtered_weak_attributes = df_attributes[(df_attributes['Overall'] < 90) 
                                                 & (df_attributes['Potential'] > p_potential)
                                                 & (df_attributes['Potential'] < 89)
                                                 & (df_attributes['FieldPositionNum'] == p_position)]

        suggested_players = filtered_weak_attributes.corrwith(player_attributes, axis=1)
        suggested_players = suggested_players.sort_values(ascending=False).head(3)

        cols = ['Name', 'Position', 'OvervalueRatio', 'Overall', 'Potential', 'Wage']
        for i, corr in enumerate(suggested_players):
            if idx == 0:
                # player 1 - suggested replacements
                replacements_p1.append(data[data.index==suggested_players.index[i]][cols].values)
            else:
                # player 2 - suggested replacements                 
                replacements_p2.append(data[data.index==suggested_players.index[i]][cols].values)

    cols1 = ['Name', 'Position', 'OvervalueRatio', 'OverallRating', 'PotentialRating', 'Wage']
    
    # suggested replacements DF for player 1 - dropping 1st row (most positively correlated = same as player 1)
    replacements_p1_df = pd.DataFrame(np.row_stack(replacements_p1), columns=cols1)
    replacements_p1_df = replacements_p1_df.drop(replacements_p1_df.index[0]).reset_index(drop=True)
    
    # suggested replacements DF for player 2 - dropping 1st row (most positively correlated = same as player 2)
    replacements_p2_df = pd.DataFrame(np.row_stack(replacements_p2), columns=cols1)
    replacements_p2_df = replacements_p2_df.drop(replacements_p2_df.index[0]).reset_index(drop=True)
    
    #adding 'Post-trade Leftover Wage' column to each returned DF
    replacements_p1_df['Post-tradeLeftoverWage'] = players_wages[0] - replacements_p1_df['Wage']
    replacements_p2_df['Post-tradeLeftoverWage'] = players_wages[1] - replacements_p2_df['Wage']
    
    #print(replacements_p1_df, '\n')
    #print(replacements_p2_df)
    
    return replacements_p1_df, replacements_p2_df

# %%
# All tables
allplayers, top2overvalued, bottom2weak = get_club_players(df_teams)
top_2, bottom_2, trades_p1_df, trades_p2_df = get_suggested_trades(df_teams)
replacements_p1_df, replacements_p2_df = get_replacement_players(df_teams)

# turning all tables into JSON
top_2 = top_2.to_json(orient='records')
bottom_2 = bottom_2.to_json(orient='records')
trades_p1_df = trades_p1_df.to_json(orient='records')
trades_p2_df = trades_p2_df.to_json(orient='records')
replacements_p1_df = replacements_p1_df.to_json(orient='records')
replacements_p2_df = replacements_p2_df.to_json(orient='records')


def all_dfs_json():
    json_dict = dict({'top2overvalued': top_2,
                     'suggestedtrades' : [trades_p1_df, trades_p2_df], 
                    'bottom2weak': bottom_2,
                     'suggestedreplacements': [replacements_p1_df, replacements_p2_df]})
    return json.dumps(json_dict)
